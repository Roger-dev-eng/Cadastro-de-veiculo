# %% [markdown]
# ### Conexão com o banco

# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine

load_dotenv(dotenv_path="../config/.env")

DATABASE_URL = os.getenv("DATABASE_URL")

engine = create_engine(DATABASE_URL)

with engine.connect() as conn:
    print("Conexão bem-sucedida com o banco de dados!")
# Out:
# Conexão bem-sucedida com o banco de dados!

# %% [markdown]
# ### Visualizar dados brutos

# %%
import pandas as pd

df = pd.read_sql("SELECT * FROM fipe_carros;", engine)
print(f"Total de registros: {len(df)}")
df.head(10)
# Out:
# Total de registros: 100
#    marca          modelo  ano_modelo combustivel     valor_str    valor  \
# 0  Acura  Integra GS 1.8      1992.0    Gasolina  R$ 10.980,00  10980.0
# 1  Acura  Integra GS 1.8      1991.0    Gasolina  R$ 10.257,00  10257.0
# 2  Acura  Legend 3.2/3.5      1998.0    Gasolina  R$ 25.134,00  25134.0
# 3  Acura  Legend 3.2/3.5      1997.0    Gasolina  R$ 22.346,00  22346.0
# 4  Acura  Legend 3.2/3.5      1996.0    Gasolina  R$ 21.013,00  21013.0
# 5  Acura  Legend 3.2/3.5      1995.0    Gasolina  R$ 18.886,00  18886.0
# 6  Acura  Legend 3.2/3.5      1994.0    Gasolina  R$ 18.076,00  18076.0
# 7  Acura  Legend 3.2/3.5      1993.0    Gasolina  R$ 16.112,00  16112.0
# 8  Acura  Legend 3.2/3.5      1992.0    Gasolina  R$ 14.647,00  14647.0
# 9  Acura  Legend 3.2/3.5      1991.0    Gasolina  R$ 14.071,00  14071.0
#
#   codigo_fipe sigla_combustivel data_consulta
# 0    038003-2                 G          None
# 1    038003-2                 G          None
# 2    038002-4                 G          None
# 3    038002-4                 G          None
# 4    038002-4                 G          None
# 5    038002-4                 G          None
# 6    038002-4                 G          None
# 7    038002-4                 G          None
# 8    038002-4                 G          None
# 9    038002-4                 G          None

# %% [markdown]
# ### Preço médio por marca

# %%
query = """
SELECT marca, ROUND(AVG(valor)::numeric, 2) AS preco_medio, COUNT(*) AS total_modelos
FROM fipe_carros
WHERE valor IS NOT NULL
GROUP BY marca
ORDER BY preco_medio DESC
LIMIT 15;
"""
df_marca = pd.read_sql(query, engine)
df_marca
# Out:
#     marca  preco_medio  total_modelos
# 0  Agrale    213013.96             85
# 1   Acura     23885.73             15

# %% [markdown]
# ##### Gráfico de barras

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.barplot(data=df_marca, y="marca", x="preco_medio", palette="Blues_r")
plt.xlabel("Preço Médio (R$)")
plt.ylabel("Marca")
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_19216\2993734636.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_marca, y="marca", x="preco_medio", palette="Blues_r")

# %% [markdown]
# ### Preço médio por tipo de combustível

# %%
query = """
SELECT combustivel, ROUND(AVG(valor)::numeric, 2) AS preco_medio, COUNT(*) AS total
FROM fipe_carros
WHERE valor IS NOT NULL
GROUP BY combustivel
ORDER BY preco_medio DESC;
"""
df_comb = pd.read_sql(query, engine)
df_comb
# Out:
#   combustivel  preco_medio  total
# 0      Diesel    213013.96     85
# 1    Gasolina     23885.73     15

# %% [markdown]
# #### Gráfico de pizza

# %%
plt.figure(figsize=(6,6))
plt.pie(df_comb["preco_medio"], labels=df_comb["combustivel"], autopct="%1.1f%%", startangle=140)
plt.title("Distribuição do Preço Médio por Combustível")
plt.show()

# %% [markdown]
# ### Evolução de preço por ano-modelo

# %%
query = """
SELECT ano_modelo, ROUND(AVG(valor)::numeric, 2) AS preco_medio
FROM fipe_carros
WHERE ano_modelo IS NOT NULL AND valor IS NOT NULL
GROUP BY ano_modelo
ORDER BY ano_modelo;
"""
df_ano = pd.read_sql(query, engine)

plt.figure(figsize=(10,5))
plt.plot(df_ano["ano_modelo"], df_ano["preco_medio"], marker="o")
plt.title("Evolução do Preço Médio por Ano do Modelo")
plt.xlabel("Ano do Modelo")
plt.ylabel("Preço Médio (R$)")
plt.grid(True)
plt.show()
